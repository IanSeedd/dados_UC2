# %%
import pandas as pd
# Biblioteca auxiliar 'openpyxl' pra ler arquivos de Excell (xlsx, ...), não precisa dar import pra funcionar

# %%
# Aqui ele pega literalmente tudo:
# df = pd.read_excel("vendas_narastore.xlsx")

# df = pd.read_excel("vendas_narastore.xlsx", usecols=["Vendedor", "Total (R$)"]) aqui usa colchete porque é uma lista de colunas
df = pd.read_excel("vendas_narastore.xlsx", usecols="A:G") # Usecols serve como um filtro para colunas, usando o nome ou posição da coluna. Funciona parecido com um range.
df

# %%
total = df["Total (R$)"].sum()
max = df["Total (R$)"].max()
min = df["Total (R$)"].min()
media = df["Total (R$)"].mean()

print(total)
print(max)
print(min)
print(media)
